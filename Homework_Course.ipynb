# %%
import random
import time

print("""
USER LOGIN
(THE PROGRAM EXPIRED WHEN THE ENTRY RIGHT IS EXPIRED AND THE CORRECT ENTRY IS MADE..)
""")
k_adi="Ebru"
k_soyadı="Somuncu"
sayac=3
while True: 
    kullanici_adi=input("Enter your Username:")
    kullanıcı_soyadı=input("Enter User Surname:")
    
    if(kullanici_adi!=k_adi and kullanıcı_soyadı==k_soyadı and sayac!=0):
        print("Username Incorrect!")
        sayac-=1
    elif(kullanici_adi==k_adi and kullanıcı_soyadı!=k_soyadı and sayac!=0):
        print("Surname Incorrect!")
        sayac-=1
    elif (kullanici_adi != k_adi and kullanıcı_soyadı!=k_soyadı and sayac != 0):
        print("Username and Surname Incorrect!")
        sayac -= 1
    else:
        print("Welcome..")
        liste=[]
        for i in range(5):
            ders=input("Please enter the 5 course you want to add:")
            liste.append(ders)
        print("LESSONS:")
        print(liste)
        print("Select at least 3 at most 5 courses from the list.!!!")
        randomsecim=[]
        for i in range(3):
            randomsecim.append(random.choice(liste))
       
        if(randomsecim[0]==randomsecim[1] or randomsecim[0]==randomsecim[2] or randomsecim[1]==randomsecim[2]):
            randomsecim.append(random.choice(liste))
        
        if(len(randomsecim)<3):
            print("You failed in class..")
        
        elif (len(randomsecim)>=3 and len(randomsecim)<6):
            print("COURSES TAKEN:")
            print(randomsecim)
            
                
            py_exam = {
                "midterm": 35,
                "final": 20,
                "project": 26
}
            exam=(0.3*py_exam["midterm"])+(0.5*py_exam["final"])+(0.2*py_exam["project"])
            print("Exam grade:",exam)
            if exam>=30:
                if(exam>90 and final>=50):
                    print("AA")
                elif exam>70 and exam<90 :
                    print("BB")
                elif exam > 50 and exam < 70:
                    print("CC")
                elif ortalamaNot > 30 and exam < 50:
                    print("DD")
                
            else:
                print("Your Note:" +format(exam,".2f"))
                print("Your Letter Grade:FF")
            
        else:
            print("You failed in class..")
            
   
    if(sayac==0):
        print("Please try again later!!")
        break
# Out:
# USER LOGIN
# (THE PROGRAM EXPIRED WHEN THE ENTRY RIGHT IS EXPIRED AND THE CORRECT ENTRY IS MADE..)
#
# Enter your Username:Ebru
# Enter User Surname:Somuncu
# Welcome..
